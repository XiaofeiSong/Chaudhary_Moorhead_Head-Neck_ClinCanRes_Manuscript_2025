# %%
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import numpy as np
import pandas as pd
import scipy.stats as stats
from matplotlib import gridspec
from statannotations.Annotator import Annotator
import palettable as pal

from scipy.stats import ranksums
from statsmodels.stats.multitest import multipletests

plt.rcParams["figure.figsize"] = (12,7)
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['figure.dpi'] = 150
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['axes.titlesize'] = 20

import sys
sys.path.append('../utility_code/')

import utils as utils
import general_utils as gen_utils

# %%
'''
colors
'''

variantC = pal.wesanderson.Moonrise6_5.mpl_colors
clinC = pal.cartocolors.qualitative.Vivid_10.mpl_colors

mappings={}
variants = ['Frame_Shift_Ins', 'Frame_Shift_Del', 'Nonsense_Mutation', 'Missense_Mutation', 'Splice_Site']
mappings['variant'] = {
    'Subclonal': {'facecolor':'none', 'edgecolor':'black', 'linewidth': 3},
    'Silent':'#FFD700',
    'Absent': {'facecolor': 'grey', 'alpha': 0.2},
    'LOH':clinC[4],
    'cn_del': 'dodgerblue', 'cn_amp':'tab:red', 'Other':'black',
    'Missense_Mutation (GoF)':'purple',
}
mappings['variant'] = mappings['variant'] | {variants[q] : variantC[q] for q in range(len(variants))}

bar_kwargs = {'width': 0.8, 'edgecolor': 'black'}

clinvars = ['Positive', 'No Response', 'MHC-Intact', 'Negative', 'MHC-LOH', 'Response', 'No Prior IO', 'Prior IO', 'History of smoking', 'No history of smoking']
mappings['clinical'] = {clinvars[q]:clinC[q] for q in range(len(clinvars))} | {'Not Assessed':{'facecolor': 'grey', 'alpha': 0.2}}
mappings['clinical']['Response'] = 'tab:green'

mappings['side'] = {'p_val': 'darkgrey', 'fdr':'darkgrey', '-log(q)':'darkgrey'}
mappings['Pdl1 Cps'] = {'PDL1_CPS >=20': 'olive', 'PDL1_CPS 1-19': 'darkkhaki', 'PDL1_CPS < 1': 'khaki', np.nan:{'facecolor': 'grey', 'alpha': 0.2}}

# %%
'''
grabbing cibersort results and merging with annotation data
'''

cib = pd.read_csv('../data/CIBERSORTx_Job16_Results.csv')

cib = cib.rename(columns={'Mixture':'analysis_id'})
# fixing mistake in annotations to ensure correct merging
cib.loc[cib['analysis_id'].str.match('M063-R-tiss'), 'analysis_id'] = 'M063-R-tiss-1'
# cib.loc[34, 'analysis_id'] = 'M063-R-tiss-1'

df_annot = pd.read_csv('../data/sample_annotations.tsv', index_col=0, sep='\t')

data = cib.merge(df_annot, on='analysis_id', how='left')

'''
creating a sum over relevant immune cell populations
'''

immune_cols = cib.columns.to_list()

for rem in ['P-value', 'Correlation', 'RMSE', 'Absolute score (sig.score)']:
    immune_cols.remove(rem)
    
# normalize absolute counts to relative counts
norm = cib[immune_cols].set_index('analysis_id')
norm = norm.div(norm.sum(axis=1), axis=0)
norm = norm.reset_index()

Cdf_raw = norm[immune_cols].melt(id_vars='analysis_id', var_name='cell_type', value_name='cell fraction')

# Cdf_raw = data[['analysis_id'] + immune_cols].melt(id_vars='analysis_id', var_name='cell_type', value_name='cell fraction')

'''
grouping cell types
'''

Cdf_raw['cell_type_coarse'] = Cdf_raw['cell_type'].astype(str)
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('B|Plasma'),'cell_type_coarse'] = 'B-cell'
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('T cells CD4'),'cell_type_coarse'] = 'T cells CD4'
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('NK'),'cell_type_coarse'] = 'NK'
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('Mono|Macro'),'cell_type_coarse'] = 'Monocytes'
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('Dendritic'),'cell_type_coarse'] = 'DC'
Cdf_raw.loc[Cdf_raw['cell_type'].str.match('Mast'),'cell_type_coarse'] = 'Mast'

Cdf_coarse = Cdf_raw.groupby(['analysis_id','cell_type_coarse'])['cell fraction'].sum().reset_index()

#remove bad sample
Cdf_coarse = Cdf_coarse[Cdf_coarse['analysis_id']!='M008-NR-met']

# merge annotations
df = Cdf_coarse.merge(df_annot, on='analysis_id', how='left')

'''
subsetting to samples with hpv_status
'''
df = df[df['hpv_status'].isin(['Positive', 'Negative'])]

'''
subsetting to most recent pre-treatment samples
'''

ids = gen_utils.list_most_recent_pretreatment_samples(df)
df = df[df['analysis_id'].isin(ids)]

df.head(2)
# Out:
#     analysis_id cell_type_coarse  cell fraction  Unnamed: 0    sample  \
# 0  M008-NR-prim           B-cell       0.011909         172  MCC008-2
# 1  M008-NR-prim               DC       0.054762         172  MCC008-2
#
#   participant pdb_original_material_type pdb_preservation_method  \
# 0      MCC008                     tissue                    FFPE
# 1      MCC008                     tissue                    FFPE
#
#   pdb_tumor_normal sequence_no  ...   best_response treatment_response  \
# 0            tumor      MCC008  ...  Stable Disease        No Response
# 1            tumor      MCC008  ...  Stable Disease        No Response
#
#    hpv_status      smoking_status preservation_method tumor_state  \
# 0    Positive  History of smoking                FFPE     primary
# 1    Positive  History of smoking                FFPE     primary
#
#   collection_date_dfd indicator participant_analysis_id      P/M
# 0                41.0      prim                 M008-NR  Primary
# 1                41.0      prim                 M008-NR  Primary
#
# [2 rows x 27 columns]

# %%
'''
p testing
'''

# Only test cell types reaching above 5% in some sample
max_frac = df.groupby('cell_type_coarse')['cell fraction'].max()
ct_test = max_frac.index[max_frac>.1]
test_idx = df['cell_type_coarse'].isin(ct_test)

ind_tests = []

for cell_type in ct_test:
    ind_tests += [
        ((cell_type, 'Positive'), (cell_type, 'Negative'))
    ]

ind_tests
# Out:
# [(('DC', 'Positive'), ('DC', 'Negative')),
#  (('Endothelial', 'Positive'), ('Endothelial', 'Negative')),
#  (('Fibroblast', 'Positive'), ('Fibroblast', 'Negative')),
#  (('Monocytes', 'Positive'), ('Monocytes', 'Negative')),
#  (('Myocyte', 'Positive'), ('Myocyte', 'Negative')),
#  (('T cells CD4', 'Positive'), ('T cells CD4', 'Negative'))]

# %%
'''
p testing
'''

def ranksum_df(df,test_field,value_field,groupby):
    vals = df[test_field].unique()
    if len(vals) != 2:
        print("Error, there must be two unique categories to test")
        return()
    res = df.groupby(groupby).apply(lambda x: ranksums(x.loc[x[test_field]==vals[0],value_field],
                                   x.loc[x[test_field]==vals[1],value_field])[1])
    res = pd.DataFrame(res)
    res.columns=['p']
    res['q'] = multipletests(res['p'],method='fdr_bh')[1]
    
    res = res.sort_values('p')
    return(res)


res = ranksum_df(df[test_idx], 'hpv_status', 'cell fraction',groupby='cell_type_coarse')
res.loc[:, 'annot'] = 'q='+round(res['q'], 3).astype('string')
res
# Out:
# /tmp/ipykernel_27474/3394260875.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   res = df.groupby(groupby).apply(lambda x: ranksums(x.loc[x[test_field]==vals[0],value_field],
#                          p         q    annot
# cell_type_coarse
# Fibroblast        0.031286  0.187717  q=0.188
# DC                0.086954  0.260862  q=0.261
# T cells CD4       0.185112  0.370224   q=0.37
# Myocyte           0.580840  0.814545  q=0.815
# Monocytes         0.678788  0.814545  q=0.815
# Endothelial       0.825199  0.825199  q=0.825

# %%
'''
summing t cell data
'''

df_t = df.loc[df['cell_type_coarse'].str.contains('T')]
df_t = df_t.groupby('analysis_id').sum(numeric_only=True).reset_index()
df_t = df_t.merge(df[['analysis_id', 'hpv_status']], on='analysis_id').drop_duplicates()
df_t.loc[:, 'cell_type'] = 'All T-Cells'

'''
ptesting
'''

tcell_p = stats.ranksums(*[df_t[df_t['hpv_status']==q]['cell fraction'] for q in ['Positive', 'Negative']]).pvalue
tcell_p_annot = 'p=' + str(round(tcell_p, 3))

ind_tests2 = [
    (('All T-Cells', 'Positive'), ('All T-Cells', 'Negative')),
]

# %%
'''
grabbing mixcr data
'''

MixCr = pd.read_csv('../data/mixcr_clonotypes.tsv', sep='\t').set_index(['Unnamed: 0', 'Unnamed: 1'])

'''
subsetting to most recent tissue sample
'''

df_annot = pd.read_csv(f'../data/sample_annotations.tsv', index_col=0, sep='\t')
samples = gen_utils.list_most_recent_tissue_samples(df_annot[(df_annot['analysis_id'].isin(MixCr.index.get_level_values(0).unique()))&(df_annot['hpv_status'].isin(['Positive', 'Negative']))])

data = MixCr.loc[samples]

# %%
'''
excluding TCR clonotypes with rearrangement that has a stop codon and sequences that have an out-of-frame sequence
'''

stop_codons = ['TGA', 'TAA', 'TAG']

for samp, idx in data.index:
    sequence = data.loc[samp].loc[idx]['targetSequences']
    
    codons = [sequence[i:i+3] for i in range(0, len(sequence), 3)]
    
    if len(set(codons).intersection(stop_codons))>0:
        print(sequence)
        
    if len(sequence)%3 != 0:
        print(sequence)
        
df_counts = pd.DataFrame(columns=['Tcell Burden'])
S = pd.read_csv('../data/sample_data-table.tsv', sep='\t').set_index('analysis_id')
for samp in samples:
    df_counts.loc[samp] = (1 + sum(data.loc[samp]['cloneCount'])) / (S.loc[samp]['gpdw_DNA_WES_twistv1_reads_aligned_in_pairs'] / (10**6))

df_counts.index.name='analysis_id'
df_counts = df_counts.reset_index()
df_counts = df_counts.rename(columns={'Tcell Burden':'cell fraction'})
df_counts.loc[:,'cell_type_coarse'] = 'MixCr Tcell Burden'
df_counts = df_counts.merge(df_annot, on='analysis_id', how='left')

mixcr_p = stats.ranksums(*[df_counts[df_counts['hpv_status']==q]['cell fraction'] for q in ['Positive', 'Negative']]).pvalue
mixcr_p_annot = 'p=' + str(round(mixcr_p, 3))

ind_tests3 = [
    (('MixCr Tcell Burden', 'Positive'), ('MixCr Tcell Burden', 'Negative')),
]

df_counts.head()
# Out:
#           analysis_id  cell fraction    cell_type_coarse  Unnamed: 0  \
# 0        M072-NR-tiss       0.144116  MixCr Tcell Burden           0
# 1      M087-NR-tiss-3       0.106181  MixCr Tcell Burden          14
# 2  M095-NR-early_tiss       0.076686  MixCr Tcell Burden          19
# 3        M031-NR-tiss       0.017134  MixCr Tcell Burden          29
# 4        M056-NR-tiss       0.045158  MixCr Tcell Burden          30
#
#              sample participant pdb_original_material_type  \
# 0       SP19-4235-A      MCC072                     tissue
# 1      WPS193634-1F      MCC087                     tissue
# 2  SP-20-0006505-B1      MCC095                     tissue
# 3         S18-56867   OSU02-031                     tissue
# 4          S19-2263   OSU02-056                     tissue
#
#   pdb_preservation_method pdb_tumor_normal   sequence_no  ...  \
# 0                    FFPE            tumor        MCC072  ...
# 1                    FFPE            tumor        MCC087  ...
# 2                    FFPE            tumor        MCC095  ...
# 3                    FFPE            tumor  19178-02-031  ...
# 4                    FFPE            tumor  19178-02-056  ...
#
#          best_response treatment_response  hpv_status      smoking_status  \
# 0       Stable Disease        No Response    Negative  History of smoking
# 1  Progressive Disease        No Response    Negative  History of smoking
# 2  Progressive Disease        No Response    Negative  History of smoking
# 3       Stable Disease        No Response    Negative  History of smoking
# 4       Stable Disease        No Response    Negative  History of smoking
#
#   preservation_method tumor_state collection_date_dfd   indicator  \
# 0                FFPE         NaN               549.0        tiss
# 1                FFPE         NaN                33.0      tiss-3
# 2                FFPE         NaN              1094.0  early_tiss
# 3                FFPE         NaN                 NaN        tiss
# 4                FFPE         NaN                 0.0        tiss
#
#   participant_analysis_id         P/M
# 0                 M072-NR     Primary
# 1                 M087-NR     Primary
# 2                 M095-NR  Metastasis
# 3                 M031-NR     Primary
# 4                 M056-NR     Primary
#
# [5 rows x 27 columns]

# %%
angle=60

fig = plt.figure(figsize=(15,8))

spec = gridspec.GridSpec(ncols=3, nrows=1,
                         width_ratios=[6, 1, 1], wspace=0.2,
                         hspace=0.5, height_ratios=[1])

ax0 = fig.add_subplot(spec[0])

order=['Negative', 'Positive']

sns.boxplot(x="cell_type_coarse",y="cell fraction", hue='hpv_status', hue_order=order, data=df, whis=1000, showfliers=False, palette=mappings['clinical'], ax=ax0)
sns.stripplot(x="cell_type_coarse",y="cell fraction", hue='hpv_status', hue_order=order, size=3, data=df, palette='dark:k', dodge=True, ax=ax0)

annot = Annotator(ax0, ind_tests, data=df, x='cell_type_coarse', y='cell fraction', hue='hpv_status', hue_order=order)
annots = res.loc[ct_test, 'annot'].to_list()
annot.configure().set_custom_annotations(annots).annotate();


plt.xticks(rotation = angle,fontsize=14);
plt.ylabel('Cell Fraction')
plt.xlabel('')
plt.ylim(0,1)

handles, labels = ax0.get_legend_handles_labels()

ax0.legend(handles[:2], ['p16 Negative', 'p16 Positive'], fontsize=13, title_fontsize=15)

ax1 = fig.add_subplot(spec[1], sharey=ax0)

sns.boxplot(x='cell_type', y='cell fraction', hue='hpv_status', data=df_t, hue_order=order, showfliers=False, whis=1000, palette=mappings['clinical'], ax=ax1)
sns.stripplot(x='cell_type', y='cell fraction', hue='hpv_status', data=df_t, hue_order=order, size=3, palette='dark:k', dodge=True, ax=ax1)
plt.xticks(rotation = angle,fontsize=14);

annot2 = Annotator(ax1, ind_tests2, data=df_t, x='cell_type', y='cell fraction', hue='hpv_status', hue_order=order)
annots = pd.Series(tcell_p_annot)
annot2.configure().set_custom_annotations(annots).annotate();

ax1.get_legend().remove()
ax1.set(ylabel='', xlabel='')


ax2 = fig.add_subplot(spec[2])

sns.boxplot(x="cell_type_coarse",y="cell fraction",hue="hpv_status", data=df_counts, whis=1000, palette=mappings['clinical'], ax=ax2)
sns.stripplot(x="cell_type_coarse",y="cell fraction",hue="hpv_status", size=3, data=df_counts, palette='dark:k', dodge=True, ax=ax2)
plt.xticks(rotation = angle, fontsize=14);

annot3 = Annotator(ax2, ind_tests3, data=df_counts, x='cell_type_coarse', y='cell fraction', hue='hpv_status', hue_order=order)
annots = pd.Series(mixcr_p_annot)
annot3.configure().set_custom_annotations(annots).annotate();

ax2.get_legend().remove()
ax2.set(ylabel='T-Cell Burden', xlabel='');
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# DC_Negative vs. DC_Positive: q=0.261
# Endothelial_Negative vs. Endothelial_Positive: q=0.825
# Fibroblast_Negative vs. Fibroblast_Positive: q=0.188
# Monocytes_Negative vs. Monocytes_Positive: q=0.815
# Myocyte_Negative vs. Myocyte_Positive: q=0.815
# T cells CD4_Negative vs. T cells CD4_Positive: q=0.37
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# All T-Cells_Negative vs. All T-Cells_Positive: p=0.143
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# MixCr Tcell Burden_Negative vs. MixCr Tcell Burden_Positive: p=0.207
